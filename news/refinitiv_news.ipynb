# %%
import refinitiv.data as rd
from refinitiv.data.content import news
from IPython.display import HTML
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
import time
import warnings
warnings.filterwarnings("ignore")
from refinitiv.data.content import symbol_conversion
# Out:
# c:\Winapp\Anaconda\lib\site-packages\pandas\core\computation\expressions.py:20:UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).

# %%
import os
import sys

# %%
sys.path.append(os.path.join(os.getcwd(), 'news'))
sys.path.append(os.path.join(os.getcwd(), 'scoring'))

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x27255ad2f40 {name='workspace'}>

# %%
def tickerToRic(ticker):
    df = symbol_conversion.Definition(
    symbols=[ticker],
    from_symbol_type=symbol_conversion.SymbolTypes.TICKER_SYMBOL,
    to_symbol_types=[
        symbol_conversion.SymbolTypes.RIC,
        symbol_conversion.SymbolTypes.OA_PERM_ID
    ],
).get_data().data.df

    return df["RIC"].iloc[0]

def ricToCompanyName(ric):
    print(symbol_conversion.Definition(symbols=ric).get_data().data.df)
    title = symbol_conversion.Definition(symbols=ric).get_data().data.df["DocumentTitle"].iloc[0]
    companyName = title.split(',')[0].split(' ')[0]
    return companyName.lower()


def getNewsFromRefintiv(ticker):
    rd.open_session()
    startdate = dNow = datetime.now().date() - timedelta(weeks=24)
    ric = tickerToRic(ticker)
    print(ric)
    companyName = ricToCompanyName(ric)
    print(companyName)
    news = rd.news.get_headlines(f"R:{ric} AND Language:LEN AND Source:RTRS AND Topic:TOPALL", start= startdate, count = 10000).reset_index()    
    realNews = news[news['headline'].str.lower().str.contains(companyName,na=False)]
    return realNews

# %%
list(getNewsFromRefintiv("MSFT")["headline"])
# Out:
# MSFT.O
#                                             DocumentTitle     RIC  \
# MSFT.O  Microsoft Corp, Ordinary Share, NASDAQ Global ...  MSFT.O
#
#            IssueISIN      CUSIP TickerSymbol IssuerOAPermID
# MSFT.O  US5949181045  594918104         MSFT     4295907168
# microsoft
# ['Microsoft president to testify before House panel over security lapses',
#  'Microsoft, BlackRock CEOs expected to attend G7 session in Italy',
#  "UPDATE 2-AI-powered Apple overtakes Microsoft as world's most valuable company",
#  "Apple beats Microsoft to return as world's most valuable company",
#  "Denmark's European Energy signs long-term power deals with Microsoft",
#  "EXCLUSIVE-MediaTek designs Arm-based chip for Microsoft's AI laptops, say sources",
#  "RPT-EXCLUSIVE-MediaTek designs Arm-based chip for Microsoft's AI laptops, say sources",
#  "EXCLUSIVE-MediaTek designs Arm-based chip for Microsoft's AI laptops, say sources",
# ...

# %%
symbol_conversion.Definition(
    symbols=["AAPL"],
    from_symbol_type=symbol_conversion.SymbolTypes.TICKER_SYMBOL,
    to_symbol_types=[
        symbol_conversion.SymbolTypes.RIC,
        symbol_conversion.SymbolTypes.OA_PERM_ID
    ],
).get_data().data.df
# Out:
#                                           DocumentTitle     RIC IssuerOAPermID
# AAPL  Apple Inc, Ordinary Share, NASDAQ Global Selec...  AAPL.O     4295905573

# %%
startdate = dNow = datetime.now().date() - timedelta(weeks=24)

# %%
aaplNews = rd.news.get_headlines("T:AAPL AND Language:LEN AND Source:RTRS AND Topic:TOPALL", start= startdate, count = 1000).reset_index()

# %%
aaplNews
# Out:
# Empty DataFrame
# Columns: [versionCreated, headline, storyId, sourceCode]
# Index: []

# %%
aaplNews[aaplNews['headline'].str.lower().str.contains("apple", na=False)]
# Out:
#          versionCreated                                           headline  \
# 8   2024-06-12 16:33:25  US STOCKS-Inflation cheer boosts Wall St ahead...
# 9   2024-06-12 14:28:15  UPDATE 2-AI-powered Apple overtakes Microsoft ...
# 10  2024-06-12 14:27:50  US STOCKS-Wall St up on inflation cheer; Apple...
# 13  2024-06-12 13:41:24  Apple beats Microsoft to return as world's mos...
# 15  2024-06-12 11:58:52  UPDATE 1-Apple becomes the first $1 trillion g...
# ..                  ...                                                ...
# 980 2024-01-02 21:48:44  US STOCKS-S&P, Nasdaq begin 2024 with lower cl...
# 982 2024-01-02 21:00:27  US STOCKS-S&P, Nasdaq end down on first sessio...
# 984 2024-01-02 19:19:53  US STOCKS-S&P, Nasdaq start 2024 in subdued fa...
# 989 2024-01-02 14:54:23  BUZZ-U.S. STOCKS ON THE MOVE-Apple, NGM Biopha...
# 990 2024-01-02 14:44:56          Apple starts 2024 with Barclays downgrade
#
#                                           storyId sourceCode
# ...
